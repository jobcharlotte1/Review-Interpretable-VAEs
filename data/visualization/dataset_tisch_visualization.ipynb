# %%
import pandas as pandas
import numpy as np
import scanpy as sc

# %%
print("hello")

# %%
1 * 1

# %%
df = pd.read_csv('gs://bs94_sur-axe-workspace-prod-a05a/datasets/PBMC_8K_CellMetainfo_table (1).tsv')
df
